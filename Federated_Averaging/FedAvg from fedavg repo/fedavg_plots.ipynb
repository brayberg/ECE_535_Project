# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#acc_mlp_iid_m10 = np.load('./acc_mlp_iid_m10.npy')
#acc_mlp_iid_m11 = np.load('./acc_mlp_iid_m11.npy')
acc_cnn_iid_m10 = np.load('./acc_cnn_iid_m10.npy')
acc_cnn_iid_m50 = np.load('./acc_cnn_iid_m50.npy')
#acc_mlp_iid_m12 = np.load('./acc_mlp_iid_m12.npy')
#acc_mlp_iid_m13= np.load('./acc_mlp_iid_m13.npy')
#acc_cnn_iid_m12 = np.load('./acc_cnn_iid_m12.npy')
#acc_cnn_iid_m50 = np.load('./acc_cnn_iid_m13.npy')



#acc_mlp_noniid_m10 = np.load('./acc_mlp_noniid_m10.npy')
#acc_mlp_noniid_m11 = np.load('./acc_mlp_noniid_m11.npy')
acc_cnn_noniid_m10 = np.load('./acc_cnn_noniid_m10.npy')
acc_cnn_noniid_m50 = np.load('./acc_cnn_noniid_m50.npy')
#acc_mlp_noniid_m12 = np.load('./acc_mlp_noniid_m12.npy')
#acc_mlp_noniid_m13 = np.load('./acc_mlp_noniid_m13.npy')
#acc_cnn_noniid_m12 = np.load('./acc_cnn_noniid_m12.npy')
#acc_cnn_noniid_m50 = np.load('./acc_cnn_noniid_m50.npy')

# %%
#test 1 (batch size 50)
x = np.arange(1,201)
plt.figure(figsize=(8,6))

plt.title("FedAvg test accuracy after $t$ rounds on iid FMNIST B=10, C=10")

plt.xlabel("Communication rounds $t$")
plt.ylabel("Test accuracy")
plt.axis([0, 200, 0.0, 1])



plt.axhline(y=0.97, color='r', linestyle='dashed')
plt.axhline(y=0.99, color='b', linestyle='dashed')

#plt.plot(x, acc_mlp_iid_m10, label='2NN, $m=50$, $E=1$, $lr=0.05$')
#plt.plot(x, acc_mlp_iid_m11, label='2NN, $m=50$, $E=1$, $lr=0.01$')
#plt.plot(x, acc_mlp_iid_m12, label='2NN, $m=50$, $E=5$, $lr=0.05$')
#plt.plot(x, acc_mlp_iid_m13, label='2NN, $m=50$, $E=5$, $lr=0.01$')

plt.plot(x, acc_cnn_iid_m10, label='CNN iid, $m=10$, $E=5$, $lr=0.01$')
plt.plot(x, acc_cnn_iid_m50, label='CNN iid, $m=10$, $E=10$, $lr=0.01$')
#plt.plot(x, acc_cnn_iid_m12, label='CNN, $m=50$, $E=10$, $lr=0.01$')
#plt.plot(x, acc_cnn_iid_m13, label='CNN, $m=50$, $E=10$, $lr=0.005$')

plt.plot(x, acc_cnn_noniid_m10, label='CNN noniid, $m=10$, $E=5$, $lr=0.01$')
plt.plot(x, acc_cnn_noniid_m50, label='CNN noniid, $m=10$, $E=10$, $lr=0.01$')

plt.legend()

plt.show()

# %%
x = np.arange(1,301)
#x2 = np.arange(1,201)
plt.figure(figsize=(8,6))

plt.title("FedAvg test accuracy after $t$ rounds on non-iid FMNIST B=10")

plt.xlabel("Communication rounds $t$")
plt.ylabel("Test accuracy")
plt.axis([0, 300, 0.4, 1])
print(len(acc_cnn_noniid_m13))

plt.axhline(y=0.97, color='r', linestyle='dashed')
plt.axhline(y=0.99, color='b', linestyle='dashed')

plt.plot(x, acc_mlp_noniid_m10, label='2NN, $m=50$, $E=1$, $lr=0.05$')
#plt.plot(x, acc_mlp_noniid_m11, label='2NN, $m=50$, $E=1$, $lr=0.01$')
#plt.plot(x, acc_mlp_noniid_m12, label='2NN, $m=50$, $E=5$, $lr=0.05$')
#plt.plot(x, acc_mlp_noniid_m13, label='2NN, $m=50$, $E=5$, $lr=0.01$')

#plt.plot(x, acc_cnn_noniid_m10, label='CNN, $m=50$, $E=5$, $lr=0.01$')
#plt.plot(x, acc_cnn_noniid_m11, label='CNN, $m=50$, $E=5$, $lr=0.005$')
#plt.plot(x, acc_cnn_noniid_m12, label='CNN, $m=50$, $E=10$, $lr=0.01$')
plt.plot(x, acc_cnn_noniid_m13, label='CNN, $m=50$, $E=10$, $lr=0.005$')




plt.legend()

plt.show()
# Out:
# 300

# %%
np.argmax(acc_cnn_iid_m12 >= 0.5)
# Out:
# 0

# %%
acc_cnn_noniid_m10
# Out:
# array([0.1001, 0.1126, 0.1004, 0.1014, 0.1117, 0.1594, 0.1357, 0.1288,
#        0.1072, 0.1762, 0.112 , 0.2047, 0.139 , 0.1039, 0.1129, 0.1637,
#        0.212 , 0.1963, 0.1495, 0.1997, 0.2528, 0.1707, 0.1459, 0.195 ,
#        0.1914, 0.245 , 0.2077, 0.2154, 0.2448, 0.2175, 0.2471, 0.1942,
#        0.1993, 0.2504, 0.1993, 0.2345, 0.2409, 0.2507, 0.2417, 0.2833,
#        0.2634, 0.2675, 0.2456, 0.2909, 0.2615, 0.2172, 0.28  , 0.2733,
#        0.2658, 0.2775, 0.1995, 0.2945, 0.2543, 0.2592, 0.2624, 0.3003,
#        0.3135, 0.2431, 0.2632, 0.1755, 0.2528, 0.282 , 0.2932, 0.2721,
#        0.2951, 0.2675, 0.2674, 0.2828, 0.2672, 0.2486, 0.286 , 0.2922,
#        0.299 , 0.2892, 0.2775, 0.3034, 0.3249, 0.3142, 0.3433, 0.2673,
#        0.2488, 0.3402, 0.297 , 0.2411, 0.2992, 0.3092, 0.2925, 0.2794,
#        0.286 , 0.2386, 0.2665, 0.3315, 0.3036, 0.2703, 0.3326, 0.3379,
#        0.3606, 0.3233, 0.3617, 0.2967])
