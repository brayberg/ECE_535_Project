# %%
# !git clone https://github.com/YuichiNAGAO/agnostic_federated_learning.git
# Out:
# Cloning into 'agnostic_federated_learning'...
# remote: Enumerating objects: 409, done.
# remote: Total 409 (delta 0), reused 0 (delta 0), pack-reused 409
# Receiving objects: 100% (409/409), 156.77 KiB | 19.60 MiB/s, done.
# Resolving deltas: 100% (254/254), done.

# %%
# !pip install tqdm
# !pip install numpy
# !pip install matplotlib
# !pip install scikit-learn
# !pip install torch

# %% [markdown]
# Fashion MNIST

# %%
# !python agnostic_federated_learning/main.py --federated_type afl --dataset fmnist --from_csv /content/agnostic_federated_learning/config/niid1
# Out:
# GPU will be used for training
#
# dataset: fmnist
# federated_type: afl
# model: cnn
# n_clients: 3
# global_epochs: 30
# local_epochs: 5
# batch_size: 32
# on_cuda: 1
# optimizer: sgd
# lr: 0.01
# data_dist: from_csv
# from_csv: /content/agnostic_federated_learning/config/niid1
# seed: 1
# seed_num: 0
# drfa_gamma: 0.01
# Class distribution of id:0
# ...

# %% [markdown]
# CIFAR-10

# %%
# !python agnostic_federated_learning/main.py --federated_type afl --dataset cifar10 --data_dist iid
# Out:
# GPU will be used for training
#
# dataset: cifar10
# federated_type: afl
# model: cnn
# n_clients: 3
# global_epochs: 30
# local_epochs: 5
# batch_size: 32
# on_cuda: 1
# optimizer: sgd
# lr: 0.01
# data_dist: iid
# from_csv: iid
# seed: 1
# seed_num: 0
# drfa_gamma: 0.01
# ...
# 100% 170498071/170498071 [00:03<00:00, 43510836.37it/s]
# Extracting /content/dataset/cifar-10-python.tar.gz to /content/dataset/
# Files already downloaded and verified
# Class distribution of id:0
# train [1654, 1689, 1673, 1658, 1658, 1655, 1636, 1678, 1664, 1701]
# test [330, 324, 337, 331, 346, 340, 344, 332, 321, 328]
# Class distribution of id:1
# train [1689, 1674, 1674, 1658, 1711, 1678, 1663, 1634, 1673, 1612]
# test [345, 332, 332, 344, 317, 344, 326, 328, 314, 351]
# Class distribution of id:2
# train [1657, 1637, 1652, 1684, 1630, 1667, 1701, 1688, 1663, 1687]
# test [325, 343, 331, 325, 337, 316, 330, 340, 365, 321]
# | Client id:0 | Test_Loss: 2.303 | Test_Acc: 11.461
# ...
